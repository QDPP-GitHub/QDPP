# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
import json
import pandas as pd
from scipy.interpolate import interp1d
sns.set(style="whitegrid")

# %%
models = [
    'dpp',
    'qmix', 
    'coma', 
#     'iql', 
#     'centralV',
    'noisemix', 
    'vdn',
    'qtran'
]

model_names = {
    'dpp': 'QPDPP (Ours)',
    'qmix': 'QMIX', 
    'coma': 'COMA', 
    'iql': 'IQL', 
    'centralV': 'CentralV',
    'noisemix': 'MAVEN', 
    'vdn': 'VDN',
    'qtran': 'QTRAN'
}

game = 'Spread-v0'
df = None

fields = ['ep_return_T', 'ep_return', 'return_mean_T', 'return_mean', 'test_return_mean_T', 'test_return_mean']

def smoothing(vs,p=0.6):
    rsts = []
    last = vs[0]
    for i, v in enumerate(vs):
        if i == 0:
            smoothed = v
        else:
            if v > 1.5 * smoothed:
                smoothed = last
            else:
                smoothed =  last*p + (1-p)*v
        rsts.append(smoothed)
        last = smoothed
    return np.array(rsts)

for model in models:
    log_dir = '../result_final/grid/{}*/{}/*/info.json'.format(game, model)
    print(log_dir)
    log_paths = glob(log_dir)
    print(log_paths)
    x_inx = None
    for path in log_paths:
        try:
            log = json.load(fp=open(path, 'r'))
            log_selected = {field:log[field] for field in fields if field in log.keys()}
        except:
            continue

        y_column = 'return_mean'
        x_column = 'return_mean_T'
        x = np.asarray(log_selected[x_column])
        if len(x) < 100:
            continue
        print(x[-1])
        if x_inx is None:
            x_inx = x
            if x_inx[-1] + 6000 > 100000:
                x_inx[-1]= 100000
        y = smoothing(smoothing(np.asarray(log_selected[y_column])))
        x = x_inx[0:len(y)]
        print(x.shape, y.shape)
        log_df = pd.DataFrame(list(zip(x, y)), 
           columns =['Step', 'Return']) 
        log_df['Model'] = log_df['Step'].apply(lambda x: model_names[model])
        log_df['run'] = log_df['Step'].apply(lambda x: path)
        if df is None:
            df = log_df

        else:
            df = pd.concat([df, log_df], ignore_index=True)
        print(path)


df = df.dropna()
df = df.astype({'Step': 'int32', 'Return': 'float32'})
# Out:
# ../result_final/grid/Spread-v0*/dpp/*/info.json
# ['../result_final/grid/Spread-v0/dpp/1/info.json', '../result_final/grid/Spread-v0/dpp/3/info.json', '../result_final/grid/Spread-v0/dpp/2/info.json']
# ../result_final/grid/Spread-v0*/qmix/*/info.json
# ['../result_final/grid/Spread-v0-1/qmix/9/info.json', '../result_final/grid/Spread-v0-1/qmix/11/info.json', '../result_final/grid/Spread-v0-1/qmix/7/info.json', '../result_final/grid/Spread-v0-1/qmix/16/info.json', '../result_final/grid/Spread-v0-1/qmix/6/info.json', '../result_final/grid/Spread-v0-1/qmix/17/info.json', '../result_final/grid/Spread-v0-1/qmix/10/info.json', '../result_final/grid/Spread-v0-1/qmix/8/info.json', '../result_final/grid/Spread-v0-1/qmix/4/info.json', '../result_final/grid/Spread-v0-1/qmix/15/info.json', '../result_final/grid/Spread-v0-1/qmix/3/info.json', '../result_final/grid/Spread-v0-1/qmix/12/info.json', '../result_final/grid/Spread-v0-1/qmix/5/info.json', '../result_final/grid/Spread-v0-1/qmix/14/info.json']
# 499301
# (498,) (498,)
# ../result_final/grid/Spread-v0-1/qmix/9/info.json
# 499460
# (498,) (499,)
# ../result_final/grid/Spread-v0-1/qmix/11/info.json
# 851428
# (498,) (848,)
# ../result_final/grid/Spread-v0-1/qmix/7/info.json
# 499541
# (498,) (995,)
# ../result_final/grid/Spread-v0-1/qmix/16/info.json
# 989829
# (498,) (987,)
# ../result_final/grid/Spread-v0-1/qmix/6/info.json
# 499732
# (498,) (999,)
# ../result_final/grid/Spread-v0-1/qmix/17/info.json
# 500040
# (498,) (499,)
# ../result_final/grid/Spread-v0-1/qmix/10/info.json
# 499794
# (498,) (500,)
# ../result_final/grid/Spread-v0-1/qmix/8/info.json
# 999953
# (498,) (999,)
# ../result_final/grid/Spread-v0-1/qmix/4/info.json
# 499207
# (498,) (994,)
# ../result_final/grid/Spread-v0-1/qmix/15/info.json
# 999456
# (498,) (996,)
# ../result_final/grid/Spread-v0-1/qmix/3/info.json
# 499844
# (498,) (996,)
# ../result_final/grid/Spread-v0-1/qmix/12/info.json
# 999056
# (498,) (996,)
# ../result_final/grid/Spread-v0-1/qmix/5/info.json
# 499255
# (498,) (991,)
# ../result_final/grid/Spread-v0-1/qmix/14/info.json
# ../result_final/grid/Spread-v0*/coma/*/info.json
# ['../result_final/grid/Spread-v0-71-30/coma/1/info.json', '../result_final/grid/Spread-v0-2/coma/1/info.json']
# 497200
# (622,) (622,)
# ../result_final/grid/Spread-v0-71-30/coma/1/info.json
# 499600
# (622,) (625,)
# ../result_final/grid/Spread-v0-2/coma/1/info.json
# ../result_final/grid/Spread-v0*/noisemix/*/info.json
# ['../result_final/grid/Spread-v0-1/noisemix/32/info.json', '../result_final/grid/Spread-v0-1/noisemix/35/info.json', '../result_final/grid/Spread-v0-1/noisemix/34/info.json', '../result_final/grid/Spread-v0-1/noisemix/33/info.json', '../result_final/grid/Spread-v0-1/noisemix/20/info.json', '../result_final/grid/Spread-v0-1/noisemix/18/info.json', '../result_final/grid/Spread-v0-1/noisemix/9/info.json', '../result_final/grid/Spread-v0-1/noisemix/11/info.json', '../result_final/grid/Spread-v0-1/noisemix/7/info.json', '../result_final/grid/Spread-v0-1/noisemix/29/info.json', '../result_final/grid/Spread-v0-1/noisemix/16/info.json', '../result_final/grid/Spread-v0-1/noisemix/6/info.json', '../result_final/grid/Spread-v0-1/noisemix/28/info.json', '../result_final/grid/Spread-v0-1/noisemix/17/info.json', '../result_final/grid/Spread-v0-1/noisemix/10/info.json', '../result_final/grid/Spread-v0-1/noisemix/19/info.json', '../result_final/grid/Spread-v0-1/noisemix/8/info.json', '../result_final/grid/Spread-v0-1/noisemix/21/info.json', '../result_final/grid/Spread-v0-1/noisemix/38/info.json', '../result_final/grid/Spread-v0-1/noisemix/36/info.json', '../result_final/grid/Spread-v0-1/noisemix/31/info.json', '../result_final/grid/Spread-v0-1/noisemix/30/info.json', '../result_final/grid/Spread-v0-1/noisemix/37/info.json', '../result_final/grid/Spread-v0-1/noisemix/39/info.json', '../result_final/grid/Spread-v0-1/noisemix/23/info.json', '../result_final/grid/Spread-v0-1/noisemix/4/info.json', '../result_final/grid/Spread-v0-1/noisemix/15/info.json', '../result_final/grid/Spread-v0-1/noisemix/3/info.json', '../result_final/grid/Spread-v0-1/noisemix/12/info.json', '../result_final/grid/Spread-v0-1/noisemix/2/info.json', '../result_final/grid/Spread-v0-1/noisemix/13/info.json', '../result_final/grid/Spread-v0-1/noisemix/5/info.json', '../result_final/grid/Spread-v0-1/noisemix/14/info.json', '../result_final/grid/Spread-v0-1/noisemix/22/info.json']
# 499837
# (995,) (995,)
# ../result_final/grid/Spread-v0-1/noisemix/32/info.json
# 499459
# (994,) (994,)
# ../result_final/grid/Spread-v0-1/noisemix/35/info.json
# 499652
# (995,) (997,)
# ../result_final/grid/Spread-v0-1/noisemix/34/info.json
# 499578
# (993,) (993,)
# ../result_final/grid/Spread-v0-1/noisemix/33/info.json
# 499545
# (995,) (995,)
# ../result_final/grid/Spread-v0-1/noisemix/29/info.json
# 499975
# (995,) (999,)
# ../result_final/grid/Spread-v0-1/noisemix/28/info.json
# 499749
# (992,) (992,)
# ../result_final/grid/Spread-v0-1/noisemix/17/info.json
# 499850
# (995,) (996,)
# ../result_final/grid/Spread-v0-1/noisemix/38/info.json
# 499684
# (995,) (996,)
# ../result_final/grid/Spread-v0-1/noisemix/36/info.json
# 499326
# (995,) (996,)
# ../result_final/grid/Spread-v0-1/noisemix/31/info.json
# 499827
# (995,) (996,)
# ../result_final/grid/Spread-v0-1/noisemix/30/info.json
# 499700
# (995,) (997,)
# ../result_final/grid/Spread-v0-1/noisemix/39/info.json
# ../result_final/grid/Spread-v0*/vdn/*/info.json
# ['../result_final/grid/Spread-v0-1/vdn/9/info.json', '../result_final/grid/Spread-v0-1/vdn/7/info.json', '../result_final/grid/Spread-v0-1/vdn/16/info.json', '../result_final/grid/Spread-v0-1/vdn/6/info.json', '../result_final/grid/Spread-v0-1/vdn/10/info.json', '../result_final/grid/Spread-v0-1/vdn/8/info.json', '../result_final/grid/Spread-v0-1/vdn/4/info.json', '../result_final/grid/Spread-v0-1/vdn/15/info.json', '../result_final/grid/Spread-v0-1/vdn/3/info.json', '../result_final/grid/Spread-v0-1/vdn/12/info.json', '../result_final/grid/Spread-v0-1/vdn/2/info.json', '../result_final/grid/Spread-v0-1/vdn/13/info.json', '../result_final/grid/Spread-v0-1/vdn/5/info.json', '../result_final/grid/Spread-v0-1/vdn/14/info.json']
# 499639
# (496,) (496,)
# ../result_final/grid/Spread-v0-1/vdn/9/info.json
# 499196
# (496,) (498,)
# ../result_final/grid/Spread-v0-1/vdn/7/info.json
# 499796
# (496,) (986,)
# ../result_final/grid/Spread-v0-1/vdn/16/info.json
# 499917
# (496,) (498,)
# ../result_final/grid/Spread-v0-1/vdn/10/info.json
# 498268
# (496,) (498,)
# ../result_final/grid/Spread-v0-1/vdn/8/info.json
# 999720
# (496,) (1000,)
# ../result_final/grid/Spread-v0-1/vdn/4/info.json
# 499219
# (496,) (997,)
# ../result_final/grid/Spread-v0-1/vdn/15/info.json
# 998744
# (496,) (996,)
# ../result_final/grid/Spread-v0-1/vdn/3/info.json
# 499532
# (496,) (994,)
# ../result_final/grid/Spread-v0-1/vdn/12/info.json
# 998693
# (496,) (998,)
# ../result_final/grid/Spread-v0-1/vdn/2/info.json
# 499879
# (496,) (991,)
# ../result_final/grid/Spread-v0-1/vdn/13/info.json
# 499133
# (496,) (998,)
# ../result_final/grid/Spread-v0-1/vdn/14/info.json
# ../result_final/grid/Spread-v0*/qtran/*/info.json
# ['../result_final/grid/Spread-v0-71-30/qtran/1/info.json', '../result_final/grid/Spread-v0-1/qtran/9/info.json', '../result_final/grid/Spread-v0-1/qtran/11/info.json', '../result_final/grid/Spread-v0-1/qtran/7/info.json', '../result_final/grid/Spread-v0-1/qtran/16/info.json', '../result_final/grid/Spread-v0-1/qtran/6/info.json', '../result_final/grid/Spread-v0-1/qtran/17/info.json', '../result_final/grid/Spread-v0-1/qtran/10/info.json', '../result_final/grid/Spread-v0-1/qtran/8/info.json', '../result_final/grid/Spread-v0-1/qtran/4/info.json', '../result_final/grid/Spread-v0-1/qtran/15/info.json', '../result_final/grid/Spread-v0-1/qtran/3/info.json', '../result_final/grid/Spread-v0-1/qtran/12/info.json', '../result_final/grid/Spread-v0-1/qtran/13/info.json', '../result_final/grid/Spread-v0-1/qtran/5/info.json', '../result_final/grid/Spread-v0-1/qtran/14/info.json', '../result_final/grid/Spread-v0-2/qtran/1/info.json']
# 499557
# (998,) (998,)
# ../result_final/grid/Spread-v0-71-30/qtran/1/info.json
# 499333
# (499,) (499,)
# ../result_final/grid/Spread-v0-1/qtran/9/info.json
# 499050
# (500,) (500,)
# ../result_final/grid/Spread-v0-1/qtran/11/info.json
# 499414
# (983,) (983,)
# ../result_final/grid/Spread-v0-1/qtran/16/info.json
# 499572
# (988,) (988,)
# ../result_final/grid/Spread-v0-1/qtran/17/info.json
# 499041
# (496,) (496,)
# ../result_final/grid/Spread-v0-1/qtran/10/info.json
# 499172
# (500,) (500,)
# ../result_final/grid/Spread-v0-1/qtran/8/info.json
# 999838
# (994,) (994,)
# ../result_final/grid/Spread-v0-1/qtran/4/info.json
# 499574
# (986,) (986,)
# ../result_final/grid/Spread-v0-1/qtran/15/info.json
# 998094
# (995,) (995,)
# ../result_final/grid/Spread-v0-1/qtran/3/info.json
# 499585
# (992,) (992,)
# ../result_final/grid/Spread-v0-1/qtran/12/info.json
# 499496
# (992,) (992,)
# ../result_final/grid/Spread-v0-1/qtran/13/info.json
# 998141
# (996,) (996,)
# ../result_final/grid/Spread-v0-1/qtran/5/info.json
# 499494
# (981,) (981,)
# ../result_final/grid/Spread-v0-1/qtran/14/info.json
# 499489
# (994,) (994,)
# ../result_final/grid/Spread-v0-2/qtran/1/info.json

# %%
plt.figure(figsize=(6,4))
sns.set(font_scale=1., style="whitegrid")
ax = sns.lineplot(x="Step", y="Return",
             hue="Model", err_style='band',
             data=df)
# plt.title(game)
plt.tight_layout(pad=1)
# ax.set_xlim(0., 200000)
# ax.set_ylim(-40., 0.)
# ax.set_yticks([-40, -30, -20, -10, -5, -3, 0])
# ax.set_xticks([0, 25000, 50000, 75000, 100000,125000, 150000, 175000, 200000])
# ax.set_xticklabels(['0', '25K', '50K', '75K', '100K', '125K', '150K', '175K', '200K'])
ax.set_xlim(0., 400000)
ax.set_ylim(0., 150.)
# ax.set_yticks([-40, -30, -20, -10, -5, -3, 0])
ax.set_xticks([0,  100000,200000, 300000,400000])
ax.set_xticklabels(['0',  '100K',  '200K',  '300K',  '400K'])
handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles=handles[1:], labels=labels[1:], 
                bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                mode="expand", borderaxespad=0, ncol=3)
plt.savefig('{}_lc.pdf'.format(game), bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# /Users/yingwen/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# log_paths = glob('./results/grid/{}/dpp/*/info.json'.format(game))
# path = log_paths[-1]
# log = json.load(fp=open(path, 'r'))
#         log_selected = {field:log[field] for field in fields}

# %%
# log.keys()
