# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
import json
import pandas as pd
from scipy.interpolate import interp1d
sns.set(style="whitegrid")

# %%
models = [
#     'qmix', 
    'dpp',
    'qmix', 
    'coma', 
#     'iql', 
#     'centralV',
    'noisemix', 
    'vdn',
    'qtran'
]

model_names = {
    'dpp': 'Q-DPP (Ours)',
    'qmix': 'QMIX', 
    'coma': 'COMA', 
    'iql': 'IQL', 
    'centralV': 'CentralV',
    'noisemix': 'MAVEN', 
    'vdn': 'VDN',
    'qtran': 'QTRAN'
}

game = 'PredatorPrey5x5-v01'
df = None

fields = [ 'return_mean_T', 'return_mean']

def smoothing(vs,p=0.95,model='vdn'):
    rsts = []
    last = vs[0]
#     if model == 'vdn':
#         vs[0:500] = vs[0:500]-2.
    for i, v in enumerate(vs):
        if i == 0:
            smoothed = v
        else:
            smoothed =  last*p + (1-p)*v
        rsts.append(smoothed)
        last = smoothed
    return np.array(rsts)

for model in models:
    log_dir = '../result_final/grid/{}*/{}/*/info.json'.format(game, model)
    log_paths = glob(log_dir)
    log_paths += glob(log_dir.replace('info.json', '*.csv'))
    print(log_paths)
    x_inx = None
    for path in log_paths:

        try:
            if 'json' in path:
                log = json.load(fp=open(path, 'r'))
                log_selected = {field:log[field] for field in fields if field in log.keys()}
            else:
#                 path = path.replsace('json', 'csv')
                log_pd = pd.read_csv(path)
#                 print(log_pd)
                log_selected = {}
                log_selected['return_mean_T']= log_pd['Step'].values
                log_selected['return_mean']= log_pd['Value'].values         
#             log_df = pd.DataFrame.from_dict(log, orient='index').transpose()
        except:
                print('read fail', path)
                continue
        y_column = 'return_mean'
        x_column = 'return_mean_T'
        x = np.asarray(log_selected[x_column])
        print(x[-1])
        if x[-1] < 1000000:
            continue
            print('length fail', path)
        y = np.asarray(log_selected[y_column])
        if len(x>1000):
            interval = int(len(x) / 1000)
            x_final = x[-1]
            idxs = list(range(0,len(x),interval))
#             idxs = (int(idx) for idx in idxs)
            x = x[idxs]
            x[-1] = x_final
            y = y[idxs]
        
        if x_inx is None:
            x_inx = x

        y = smoothing(smoothing(np.asarray(y), model=model))
        x = x_inx[0:len(y)]
        print(x.shape, y.shape)
        log_df = pd.DataFrame(list(zip(x, y)), 
           columns =['Step', 'Return']) 
#         print(lod_df)
        log_df['Model'] = log_df['Step'].apply(lambda x: model_names[model])
        log_df['run'] = log_df['Step'].apply(lambda x: path)
#             log_df.columns = ['Model', 'Step', 'Return', 'run']
        if df is None:
            df = log_df

        else:
            df = pd.concat([df, log_df], ignore_index=True)
        print(path)

df = df.dropna()
df = df.astype({'Step': 'int32', 'Return': 'float32'})
# Out:
# ['../result_final/grid/PredatorPrey5x5-v01/dpp/4/info.json', '../result_final/grid/PredatorPrey5x5-v01/dpp/1/info.csv', '../result_final/grid/PredatorPrey5x5-v01/dpp/4/info.bak.csv', '../result_final/grid/PredatorPrey5x5-v01/dpp/2/info.csv', '../result_final/grid/PredatorPrey5x5-v01-81-03/dpp/1/run-grid_PredatorPrey5x5-v01_dpp_3_tb_logs_dpp__2020-02-01_14-24-20-tag-return_mean.csv']
# read fail ../result_final/grid/PredatorPrey5x5-v01/dpp/4/info.json
# 4399153
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01/dpp/1/info.csv
# 4999885
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01/dpp/4/info.bak.csv
# 4999828
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01/dpp/2/info.csv
# 4374841
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01-81-03/dpp/1/run-grid_PredatorPrey5x5-v01_dpp_3_tb_logs_dpp__2020-02-01_14-24-20-tag-return_mean.csv
# ['../result_final/grid/PredatorPrey5x5-v01/qmix/1/info.json', '../result_final/grid/PredatorPrey5x5-v01-71-30/qmix/1/info.json', '../result_final/grid/PredatorPrey5x5-v01/qmix/2/info.csv', '../result_final/grid/PredatorPrey5x5-v01-81-03/qmix/1/run-grid_PredatorPrey5x5-v01_qmix_1_tb_logs_qmix__2020-02-03_23-18-47-tag-return_mean.csv', '../result_final/grid/PredatorPrey5x5-v01-81-03/qmix/1/run-grid_PredatorPrey5x5-v01_qmix_1_tb_logs_qmix__2020-02-02_23-30-14-tag-return_mean.csv']
# 3864
# 4999531
# (1096,) (1096,)
# ../result_final/grid/PredatorPrey5x5-v01-71-30/qmix/1/info.json
# 4999719
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01/qmix/2/info.csv
# 4999832
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01-81-03/qmix/1/run-grid_PredatorPrey5x5-v01_qmix_1_tb_logs_qmix__2020-02-03_23-18-47-tag-return_mean.csv
# 4999837
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01-81-03/qmix/1/run-grid_PredatorPrey5x5-v01_qmix_1_tb_logs_qmix__2020-02-02_23-30-14-tag-return_mean.csv
# ['../result_final/grid/PredatorPrey5x5-v01-71-30/coma/1/info.json', '../result_final/grid/PredatorPrey5x5-v01/coma/1/info.csv', '../result_final/grid/PredatorPrey5x5-v01-81-03/coma/1/run-grid_PredatorPrey5x5-v01_coma_1_tb_logs_coma__2020-02-03_23-18-57-tag-return_mean.csv', '../result_final/grid/PredatorPrey5x5-v01-81-03/coma/1/run-grid_PredatorPrey5x5-v01_coma_1_tb_logs_coma__2020-02-02_23-30-44-tag-return_mean.csv']
# 5000105
# (1077,) (1077,)
# ../result_final/grid/PredatorPrey5x5-v01-71-30/coma/1/info.json
# 5000374
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01/coma/1/info.csv
# 5000337
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01-81-03/coma/1/run-grid_PredatorPrey5x5-v01_coma_1_tb_logs_coma__2020-02-03_23-18-57-tag-return_mean.csv
# 5000545
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01-81-03/coma/1/run-grid_PredatorPrey5x5-v01_coma_1_tb_logs_coma__2020-02-02_23-30-44-tag-return_mean.csv
# ['../result_final/grid/PredatorPrey5x5-v01-71-30/noisemix/1/info.json', '../result_final/grid/PredatorPrey5x5-v01/noisemix/1/info.csv', '../result_final/grid/PredatorPrey5x5-v01/noisemix/2/info.csv']
# 4050803
# (1136,) (1136,)
# ../result_final/grid/PredatorPrey5x5-v01-71-30/noisemix/1/info.json
# 4371505
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01/noisemix/1/info.csv
# 3842808
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01/noisemix/2/info.csv
# ['../result_final/grid/PredatorPrey5x5-v01-71-30/vdn/1/info.json', '../result_final/grid/PredatorPrey5x5-v01/vdn/1/info.csv']
# 4997447
# (1076,) (1076,)
# ../result_final/grid/PredatorPrey5x5-v01-71-30/vdn/1/info.json
# 4999617
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01/vdn/1/info.csv
# ['../result_final/grid/PredatorPrey5x5-v01/qtran/1/info.csv', '../result_final/grid/PredatorPrey5x5-v01-81-03/qtran/1/run-grid_PredatorPrey5x5-v01_qtran_1_tb_logs_qtran__2020-02-03_14-56-05-tag-return_mean.csv', '../result_final/grid/PredatorPrey5x5-v01-81-03/qtran/1/run-grid_PredatorPrey5x5-v01_qtran_1_tb_logs_qtran__2020-02-04_14-59-52-tag-return_mean.csv']
# 4999906
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01/qtran/1/info.csv
# 4999960
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01-81-03/qtran/1/run-grid_PredatorPrey5x5-v01_qtran_1_tb_logs_qtran__2020-02-03_14-56-05-tag-return_mean.csv
# 3824111
# (1000,) (1000,)
# ../result_final/grid/PredatorPrey5x5-v01-81-03/qtran/1/run-grid_PredatorPrey5x5-v01_qtran_1_tb_logs_qtran__2020-02-04_14-59-52-tag-return_mean.csv

# %%
plt.figure(figsize=(6,4))
sns.set(font_scale=1., style="whitegrid")
ax = sns.lineplot(x="Step", y="Return",
             hue="Model", err_style='band',
             data=df)
# plt.title(game)
plt.tight_layout(pad=1)
ax.set_xlim(0., 4000000)
ax.set_ylim(-15., 5.)
ax.set_yticks([ -15,-10, -5, 0, 5])
ax.set_xticks([0, 1000000, 2000000, 3000000, 4000000])
ax.set_xticklabels(['0', '1M', '2M', '3M', '4M'])
ax.axhline(y=4, linewidth=1, color='grey', ls='--')
handles, labels = ax.get_legend_handles_labels()
lgd = ax.legend(handles=handles[1:], labels=labels[1:], 
                bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                mode="expand", borderaxespad=0, ncol=3)
plt.savefig('{}_lc.pdf'.format(game), bbox_extra_artists=(lgd,), bbox_inches='tight', )
# Out:
# /Users/yingwen/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# log_paths = glob('./results/grid/{}/dpp/*/info.json'.format(game))
# path = log_paths[-1]
# log = json.load(fp=open(path, 'r'))
#         log_selected = {field:log[field] for field in fields}

# %%
# log.keys()

# %%
B = np.random.randn(9, 3)
C = np.dot(B.T,  B)
L = np.dot(B,  B.T)
print(B.shape, C.shape)
# Out:
# (9, 3) (3, 3)

# %%
u, Bs, vh = np.linalg.svd(B)
print(Bs)
# Out:
# [3.36623899 2.51360481 1.99106744]

# %%
u, Cs, vh = np.linalg.svd(C)
print(np.sqrt(Cs))
# Out:
# [3.36623899 2.51360481 1.99106744]

# %%
u, Ls, vh = np.linalg.svd(L)
print(Ls)
# Out:
# [1.13315650e+01 6.31820913e+00 3.96434956e+00 1.03377392e-15
#  3.16232997e-16 2.47026911e-16 2.34161196e-16 1.37709318e-16
#  7.57730887e-18]
